# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/GdriveXbot/16cbaf00248311ed.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/test/50564.txt
#   inflating: dataset/test/50571.txt
#   inflating: dataset/test/50581.txt
#   inflating: dataset/test/50583.txt
#   inflating: dataset/test/50587.txt
#   inflating: dataset/test/50603.txt
#   inflating: dataset/test/50609.txt
#   inflating: dataset/test/50612.txt
#   inflating: dataset/test/50617.txt
#   inflating: dataset/test/50628.txt
#   inflating: dataset/test/50644.txt
#   inflating: dataset/test/50647.txt
#   inflating: dataset/test/50650.txt
#   inflating: dataset/test/50658.txt
#   inflating: dataset/test/50697.txt
#   inflating: dataset/test/50698.txt
#   inflating: dataset/test/50705.txt
#   inflating: dataset/test/50723.txt
#   inflating: dataset/test/50728.txt
#   inflating: dataset/test/50733.txt
#   inflating: dataset/test/50746.txt
#   inflating: dataset/test/50750.txt
#   inflating: dataset/test/50769.txt
#   inflating: dataset/test/50780.txt
# ...

# %%
import glob
with open('test.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/test*.txt'):
        with open(path) as txt_file:
            txt = txt_file.read() + '\n'
            csv_file.write(txt)

# %%
import glob
with open('train.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/train/*.txt'):
        with open(path) as txt_file:
            txt = txt_file.read() + '\n'
            csv_file.write(txt)

# %%
path='/content/dataset/train/0.txt'

# %%
name=[]

# %%
s=[]

# %%
v=[]

# %%
f=open(path,"r")
lines=f.readlines()
result=[]
for x in lines:
    b=x.split()
    result.append(b[1])

# %%
name=[]

# %%
f=open(path,"r")
lines=f.readlines()
result=[]
for x in lines:
    b=x.split()
    if len(b)>2:
      b.pop(1)
    else:
      pass  
    name.append(b[0])

# %%
name
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weather',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken',
#  'Name:']

# %%
result=[]

# %%
my=[]

# %%
my=[]

# %%
n=[]
import glob
for file in glob.glob('/content/dataset/test/*.txt'):
  n.append(file)
  f=open(file,"r")

  lines=f.readlines()
  result=[]
  for x in lines:
    b=x.split()
    if len(b)>2:
      b.pop(1)
    else:
        pass
    result.append(b[1])
  my.append(result)

# %%
my[0][0]
# Out:
# '0x85b0'

# %%
j[0]
# Out:
# '55116'

# %%
 '/content/dataset/test/47070.txt',
 '/content/dataset/test/51944.txt',

# %%
n

# %%
j=[]

# %%
len(j)
# Out:
# 11399

# %%
for i in n:
  t=i.split('/')
  y=t[-1]
  m=y.split('.')
  u=m[0]
  j.append(u)

# %%
n

# %%
my[0]
# Out:
# ['0xb7dc',
#  'BANGRES08DEL03',
#  '31.000000',
#  '4.200000',
#  '12.906229',
#  '77.596791',
#  '12.936229',
#  '77.626791',
#  '26-03-2022',
#  '23:20',
#  '23:25',
#  'Stormy',
#  'Low',
#  '0',
#  'Drinks',
#  'motorcycle',
#  '1.000000',
#  'No',
#  'Metropolitian',
#  'dtype:']

# %%
my=[]
with open('train.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/test*.txt'):
        my.append(result)
        with open(path) as txt_file:
            txt = txt_file.readlines()
            
            for x,u in enumerate(txt):
              #print(x)
              b=u.split()
              if len(b)>2:
                #print(b)
                b=b.pop(1)
                #print(b)
              else:
                pass  
              result.append(b[1])

# %%
v
# Out:
# ['Sunny', '24.000000', 'dtype:']

# %%
len(s)
# Out:
# 21

# %%
name
# Out:
# ['ID',
#  'Delivery_person_ID',
#  'Delivery_person_Age',
#  'Delivery_person_Ratings',
#  'Restaurant_latitude',
#  'Restaurant_longitude',
#  'Delivery_location_latitude',
#  'Delivery_location_longitude',
#  'Order_Date',
#  'Time_Orderd',
#  'Time_Order_picked',
#  'Weather',
#  'Road_traffic_density',
#  'Vehicle_condition',
#  'Type_of_order',
#  'Type_of_vehicle',
#  'multiple_deliveries',
#  'Festival',
#  'City',
#  'Time_taken',
#  'Name:',
#  '0x4607',
#  'INDORES13DEL02',
#  '37.000000',
#  '4.900000',
#  '22.745049',
#  '75.892471',
#  '22.765049',
#  '75.912471',
#  '19-03-2022',
#  '11:30',
#  '11:45',
#  'conditions',
#  'High',
#  '2',
#  'Snack',
#  'motorcycle',
#  '0.000000',
#  'No',
#  'Urban',
#  '(min)',
#  '0,']

# %%
len(txt[1].split())

# %%
import numpy as np

# %%
with open('train.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/train/*.txt'):
        with open(path) as txt_file:
            txt = txt_file.readlines()

# %%
y=[1,2,3]
i=[]
i.append(y)

# %%
i
# Out:
# [[1, 2, 3]]

# %%
my=[]
result=[]

# %%
import glob
#result=np.array()
my=[]
with open('train.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/train/*.txt'):
        my.append(result)
        with open(path) as txt_file:
            txt = txt_file.readlines()
            
            for x,u in enumerate(txt):
              #print(x)
              b=u.split()
              result.append(b[1])

# %%
import glob
#result=np.array()
my=[]
with open('train.csv', 'a') as csv_file:
    for path in glob.glob('/content/dataset/train/*.txt'):
        my.append(result)
        with open(path) as txt_file:
            txt = txt_file.readlines()
            
            for x,u in enumerate(txt):
              #print(x)
              b=u.split()
              result.append(b[1])

# %%
type(my)
# Out:
# list

# %%
len(my)
# Out:
# 45593

# %%
my_array = np.asarray(my)

# %%
my_array.shape
# Out:
# (11399, 20)

# %%
my_array
# Out:
# array([['0xb7dc', 'BANGRES08DEL03', '31.000000', ..., 'No',
#         'Metropolitian', 'dtype:'],
#        ['0x1adc', 'VADRES02DEL02', '20.00', ..., 'No', 'NaN', 'dtype:'],
#        ['0xca5f', 'KOCRES11DEL02', '39.000000', ..., 'No',
#         'Metropolitian', 'dtype:'],
#        ...,
#        ['0x4a0a', 'MYSRES02DEL01', '23.000000', ..., 'No', 'Urban',
#         'dtype:'],
#        ['0xb845', 'PUNERES07DEL01', '20.000000', ..., 'No',
#         'Metropolitian', 'dtype:'],
#        ['0x23e9', 'SURRES09DEL01', '30.000000', ..., 'No', 'NaN',
#         'dtype:']], dtype='<U17')

# %%
import pandas as pd

# %%
df_test = pd.DataFrame(my_array)

# %%
df_test.columns=['ID',
 'Delivery_person_ID',
 'Delivery_person_Age',
 'Delivery_person_Ratings',
 'Restaurant_latitude',
 'Restaurant_longitude',
 'Delivery_location_latitude',
 'Delivery_location_longitude',
 'Order_Date',
 'Time_Orderd',
 'Time_Order_picked',
 'Weather',
 'Road_traffic_density',
 'Vehicle_condition',
 'Type_of_order',
 'Type_of_vehicle',
 'multiple_deliveries',
 'Festival',
 'City',
 'Name:']

# %%
name

# %%
us=['ID',
 'Delivery_person_ID',
 'Delivery_person_Age',
 'Delivery_person_Ratings',
 'Restaurant_latitude',
 'Restaurant_longitude',
 'Delivery_location_latitude',
 'Delivery_location_longitude',
 'Order_Date',
 'Time_Orderd',
 'Time_Order_picked',
 'Weather',
 'Road_traffic_density',
 'Vehicle_condition',
 'Type_of_order',
 'Type_of_vehicle',
 'multiple_deliveries',
 'Festival',
 'City']

# %%
df_test_n=df_test[us]

# %%
df_test_n.head()
# Out:
#        ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0xb7dc     BANGRES08DEL03           31.000000                4.200000
# 1  0x1adc      VADRES02DEL02               20.00                    4.70
# 2  0xca5f      KOCRES11DEL02           39.000000                4.900000
# 3  0x2fd7      VADRES08DEL03               28.00                    4.90
# 4  0x52d1      MYSRES14DEL03               24.00                    4.00
#
#   Restaurant_latitude Restaurant_longitude Delivery_location_latitude  \
# 0           12.906229            77.596791                  12.936229
# 1                0.00                 0.00                       0.08
# 2           10.006881            76.345397                  10.056881
# 3                0.00                 0.00                       0.06
# 4                0.00                 0.00                       0.09
#
#   Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
df_test_n.to_csv('test_or.csv',index=False)

# %%
ss=pd.read_csv('/content/dataset/sample_submission.csv')

# %%
ss.to_csv('sa_sub.csv',index=False)

# %%
t=pd.read_csv('/content/drive/MyDrive/hacker_earth/amazon_hiring/train_or.csv')
t.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x1c92    COIMBRES03DEL02                 39.0                      5.0
# 1  0xaaab      VADRES07DEL01                 36.0                      4.7
# 2   0x463      VADRES20DEL03                  NaN                      NaN
# 3  0xacec   RANCHIRES07DEL01                 37.0                      4.2
# 4  0xb9cc      HYDRES01DEL02                 38.0                      3.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.025083             77.015393                   11.045083
# 1             0.000000              0.000000                    0.070000
# 2           -22.311358            -73.164798                   22.371358
# 3            23.359407             85.325055                   23.469407
# 4            17.410371             78.437225                   17.540371
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
ss
# Out:
#        ID  Time_taken (min)
# 0  0x7faf              25.0
# 1  0x4607              24.0
# 2  0xb379              33.0
# 3  0x7804              19.0
# 4  0x20f7              42.0

# %%
df_new=df[us]
df_new.head()
# Out:
#        ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x1c92    COIMBRES03DEL02           39.000000                5.000000
# 1  0xaaab      VADRES07DEL01               36.00                    4.70
# 2   0x463      VADRES20DEL03                 NaN                     NaN
# 3  0xacec   RANCHIRES07DEL01           37.000000                4.200000
# 4  0xb9cc      HYDRES01DEL02           38.000000                3.700000
#
#   Restaurant_latitude Restaurant_longitude Delivery_location_latitude  \
# 0           11.025083            77.015393                  11.045083
# 1                0.00                 0.00                       0.07
# 2          -22.311358           -73.164798                  22.371358
# 3           23.359407            85.325055                  23.469407
# 4           17.410371            78.437225                  17.540371
#
#   Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
# %cd "/content/drive/MyDrive/hacker_earth/amazon_hiring"
# Out:
# /content/drive/MyDrive/hacker_earth/amazon_hiring

# %%
df_new.to_csv('train_or.csv',index=False)

# %%
import numpy

# %%
my=[]

# %%
import glob
for file in glob.glob('/content/dataset/train/*.txt'):
  f=open(file,"r")
  lines=f.readlines()
  result=[]
  for x in lines:
    b=x.split()
    result.append(b[1])
  my.append(result)

# %%
matrix = numpy.empty(shape=(21, 5), dtype='object')
print(matrix)

# %%
type(result)
# Out:
# list

# %%
   f=open(file,"r")
    lines=f.readlines()
    result=[]
    for x in lines:
      b=x.split()
      result.append(b[])

# %%
file='/content/dataset/train/0.txt'

# %%
len(result)
# Out:
# 21

# %%
result
# Out:
# ['0x4607',
#  'INDORES13DEL02',
#  '37.000000',
#  '4.900000',
#  '22.745049',
#  '75.892471',
#  '22.765049',
#  '75.912471',
#  '19-03-2022',
#  '11:30',
#  '11:45',
#  'conditions',
#  'High',
#  '2',
#  'Snack',
#  'motorcycle',
#  '0.000000',
#  'No',
#  'Urban',
#  '(min)',
#  '0,']

# %%
txt

# %%
with open(path) as txt_file:
            txt = txt_file.read()

# %%
txt

# %%
len(contents)
# Out:
# 21

# %%
with open(path) as f:
    contents = f.readlines()

# %%
type(contents)
# Out:
# list

# %%
print(i-1)

# %%
len(contents[0].split(' '))
# Out:
# 38

# %%
t=contents[0].split(' ')[37]

# %%
t
# Out:
# '0x4607\n'

# %%
for i in contents:
  print(i)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
from lightgbm import LGBMRegressor
import xgboost as xgb
import datetime
from sklearn.preprocessing import LabelEncoder

# %%
ss=pd.read_csv('/content/dataset/sample_submission.csv')
train = pd.read_csv('train.csv' )
test = pd.read_csv('test.csv')

# %%
train.head()

# %%
df
# Out:
#            ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x1c92    COIMBRES03DEL02           39.000000                5.000000
# 1      0xaaab      VADRES07DEL01               36.00                    4.70
# 2       0x463      VADRES20DEL03                 NaN                     NaN
# 3      0xacec   RANCHIRES07DEL01           37.000000                4.200000
# 4      0xb9cc      HYDRES01DEL02           38.000000                3.700000
# ...       ...                ...                 ...                     ...
# 45588  0x6498      HYDRES17DEL01           39.000000                4.700000
# 45589  0x839c      VADRES07DEL02               34.00                    4.30
# 45590  0x5b84   RANCHIRES05DEL01           31.000000                4.000000
# 45591  0x9886      JAPRES18DEL01           36.000000                4.400000
# 45592  0x7f91      VADRES05DEL02           28.000000                4.100000
#
# ...

# %%
df.columns=name

# %%
df[df.ID=='0x4607']
# Out:
#            ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 21661  0x4607     INDORES13DEL02           37.000000                4.900000
#
#       Restaurant_latitude Restaurant_longitude Delivery_location_latitude  \
# 21661           22.745049            75.892471                  22.765049
#
#       Delivery_location_longitude  Order_Date Time_Orderd  ...     Weather  \
# 21661                   75.912471  19-03-2022       11:30  ...  conditions
#
#       Road_traffic_density Vehicle_condition Type_of_order Type_of_vehicle  \
# 21661                 High                 2         Snack      motorcycle
#
#       multiple_deliveries Festival   City Time_taken Name:
# 21661            0.000000       No  Urban      (min)    0,
#
# [1 rows x 21 columns]

# %%
df

# %%
df['Name:']
# Out:
# 0         4110,
# 1        32400,
# 2        24346,
# 3        20352,
# 4         6410,
#           ...
# 45588    25158,
# 45589    31881,
# 45590    22490,
# 45591    30527,
# 45592    22498,
# Name: Name:, Length: 45593, dtype: object
